# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Wrangling

# %%
df = pd.read_csv('Data/nfl_player_stats_by_career_2020.csv')

# %%
# set option so I'm able to see all my columns
pd.set_option('display.max_columns', None)

#I've filtered out non-QBs by including only player's who've thrown over 1000 passes in there career
# in the modern nfl a quarter back will throw 1000 passes in about 3 seasons.
qb_df = df[df['attempted_passes'] > 800]

#dropped all columns that do not pertain to QBs.
qb_df = qb_df.dropna(axis=1)

#dropped unnecessary columns
qb_df.drop(columns=['id', 'sacks', 'year', 'fumbles_recovered', 'fumbles_recovered_for_touchdown', 
                    'longest_pass', 'longest_rush', 'touches', 'yards_lost_to_sacks', 'yards_per_touch',
                    'yards_recovered_from_fumble', 'birth_date', 'height', 'weight', 'season', 'approximate_value'], inplace=True, errors='ignore')


#split-up and dropped the qb_record column
qb_df[['win','loss', 'tie']] = qb_df['qb_record'].str.split('-',expand=True)

qb_df = qb_df.astype({'win': 'int64', 'loss': 'int64','tie': 'int64'})

qb_df.drop(columns=['qb_record'], inplace=True)

# %%
#import and wrangler HOF csv.
hof = pd.read_csv('Data/Hall of Fame List.csv')

hof['hof'] = 1

hof = hof[['name', 'hof']]

hof
# Out:
#                   name  hof
# 0        Steve Atwater    1
# 1          Isaac Bruce    1
# 2    Harold Carmichael    1
# 3         Jimbo Covert    1
# 4         Bobby Dillon    1
# ..                 ...  ...
# 289        Cal Hubbard    1
# 290         Don Hutson    1
# 291    Bronko Nagurski    1
# 292       Ernie Nevers    1
# 293         Jim Thorpe    1
#
# [294 rows x 2 columns]

# %%
#merged qb and HOF datasets
qb_df = pd.merge(qb_df, hof, on='name', how='left')

qb_df.set_index('player_id', inplace=True)

# %%
#data cleaning
qb_df.drop(columns='name', inplace=True)
qb_df['hof'] = qb_df['hof'].replace(np.NaN, 0)

# %%
#import/wrangle/merge player season data to get years played in NFL
sdf = pd.read_csv('Data/nfl_player_stats_by_season_2020.csv')

sdf_qb = sdf[sdf['player_id'].isin(qb_df.index)]

sdf_pb_group = sdf_qb.groupby('player_id').agg(start_year = ('season' , 'min'), end_year = ('season', 'max'))

qb_df = pd.merge(qb_df, sdf_pb_group, on='player_id', how='left')

#filtered out active/ineligible QBs from the data set
test = qb_df[qb_df['end_year'] >= 2015]
qb_df = qb_df[qb_df['end_year'] < 2015]

# %%
qb_df
# Out:
#            adjusted_net_yards_per_pass_attempt  adjusted_yards_per_attempt  \
# player_id
# CampJa00                                  5.47                         6.3
# OrtoKy00                                  5.54                         6.3
# PondCh00                                  4.60                         5.5
# CarrDa00                                  4.34                         5.5
# BatcCh00                                  5.14                         6.2
# ...                                        ...                         ...
# BratZe00                                  4.14                         4.1
# StarBa00                                  6.55                         6.8
# RyanFr00                                  6.55                         6.6
# TensSt00                                  4.58                         5.0
# KappJo00                                  3.50                         4.2
#
#            attempted_passes  completed_passes  fourth_quarter_comebacks  \
# player_id
# CampJa00             2518.0            1519.0                       7.0
# OrtoKy00             2712.0            1613.0                       8.0
# PondCh00             1057.0             632.0                       2.0
# CarrDa00             2267.0            1353.0                       7.0
# BatcCh00             1604.0             908.0                       9.0
# ...                     ...               ...                       ...
# BratZe00             1484.0             762.0                       5.0
# StarBa00             3149.0            1808.0                      18.0
# RyanFr00             2133.0            1090.0                       8.0
# TensSt00              862.0             369.0                       1.0
# KappJo00              918.0             449.0                       4.0
#
#            fumbles  game_winning_drives  games  games_started  \
# player_id
# CampJa00      52.0                 10.0   90.0           79.0
# OrtoKy00      35.0                  9.0   87.0           82.0
# PondCh00      20.0                  3.0   38.0           36.0
# CarrDa00      71.0                 11.0   94.0           79.0
# BatcCh00      24.0                 11.0   81.0           55.0
# ...            ...                  ...    ...            ...
# BratZe00      28.0                  7.0  132.0           49.0
# StarBa00      64.0                 17.0  196.0          157.0
# RyanFr00      42.0                  9.0  126.0           87.0
# TensSt00      14.0                  1.0   56.0           34.0
# KappJo00       9.0                  4.0   51.0           48.0
#
#            interception_percentage  interceptions_thrown  \
# player_id
# CampJa00                       2.4                  60.0
# OrtoKy00                       2.5                  69.0
# PondCh00                       3.4                  36.0
# CarrDa00                       3.1                  71.0
# BatcCh00                       3.2                  52.0
# ...                            ...                   ...
# BratZe00                       8.2                 122.0
# StarBa00                       4.4                 138.0
# RyanFr00                       5.2                 111.0
# TensSt00                       5.3                  46.0
# KappJo00                       7.0                  64.0
#
#            net_yards_per_pass_attempt  passing_completion  \
# player_id
# CampJa00                         5.83                60.3
# OrtoKy00                         5.92                59.5
# PondCh00                         5.34                59.8
# CarrDa00                         5.09                59.7
# BatcCh00                         5.78                56.6
# ...                               ...                 ...
# BratZe00                         6.96                51.3
# StarBa00                         7.54                57.4
# RyanFr00                         7.49                51.1
# TensSt00                         5.93                42.8
# KappJo00                         5.63                48.9
#
#            passing_touchdown_percentage  passing_touchdowns  passing_yards  \
# player_id
# CampJa00                            3.5                87.0        16771.0
# OrtoKy00                            3.7               101.0        18037.0
# PondCh00                            3.6                38.0         6658.0
# CarrDa00                            2.9                65.0        14452.0
# BatcCh00                            3.8                61.0        11085.0
# ...                                 ...                 ...            ...
# BratZe00                            4.4                65.0        10345.0
# StarBa00                            4.8               152.0        24718.0
# RyanFr00                            7.0               149.0        16042.0
# TensSt00                            5.0                43.0         5558.0
# KappJo00                            4.4                40.0         5911.0
#
#            passing_yards_per_attempt  quarterback_rating  rush_attempts  \
# player_id
# CampJa00                         6.7                81.7          240.0
# OrtoKy00                         6.7                81.2          126.0
# PondCh00                         6.3                75.9          126.0
# CarrDa00                         6.4                74.9          305.0
# BatcCh00                         6.9                77.2          172.0
# ...                              ...                 ...            ...
# BratZe00                         7.0                54.3           92.0
# StarBa00                         7.8                80.5          247.0
# RyanFr00                         7.5                77.6          310.0
# TensSt00                         6.4                59.0           47.0
# KappJo00                         6.4                55.1          119.0
#
#            rush_attempts_per_game  rush_touchdowns  rush_yards  \
# player_id
# CampJa00                      2.7              6.0      1204.0
# OrtoKy00                      1.4              4.0       296.0
# PondCh00                      3.3              7.0       639.0
# CarrDa00                      3.2              9.0      1328.0
# BatcCh00                      2.1              6.0       637.0
# ...                           ...              ...         ...
# BratZe00                      0.7              5.0       308.0
# StarBa00                      1.3             15.0      1308.0
# RyanFr00                      2.5              6.0      1358.0
# TensSt00                      0.8              0.0        82.0
# KappJo00                      2.3              5.0       611.0
#
#            rush_yards_per_attempt  rush_yards_per_game  \
# player_id
# CampJa00                      5.0                 13.4
# OrtoKy00                      2.3                  3.4
# PondCh00                      5.1                 16.8
# CarrDa00                      4.4                 14.1
# BatcCh00                      3.7                  7.9
# ...                           ...                  ...
# BratZe00                      3.3                  2.3
# StarBa00                      5.3                  6.7
# RyanFr00                      4.4                 10.8
# TensSt00                      1.7                  1.5
# KappJo00                      5.1                 12.0
#
#            rushing_and_receiving_touchdowns  times_sacked  \
# player_id
# CampJa00                                6.0         170.0
# OrtoKy00                                4.0         165.0
# PondCh00                                7.0          95.0
# CarrDa00                                9.0         267.0
# BatcCh00                                6.0         161.0
# ...                                     ...           ...
# BratZe00                                5.0           1.0
# StarBa00                               15.0          59.0
# RyanFr00                                7.0           4.0
# TensSt00                                0.0          35.0
# KappJo00                                5.0          55.0
#
#            yards_from_scrimmage  yards_per_completed_pass  \
# player_id
# CampJa00                 1204.0                      11.0
# OrtoKy00                  296.0                      11.2
# PondCh00                  624.0                      10.5
# CarrDa00                 1328.0                      10.7
# BatcCh00                  637.0                      12.2
# ...                         ...                       ...
# BratZe00                  308.0                      13.6
# StarBa00                 1308.0                      13.7
# RyanFr00                 1389.0                      14.7
# TensSt00                   82.0                      15.1
# KappJo00                  611.0                      13.2
#
#            yards_per_game_played  win  loss  tie  hof  start_year  end_year
# player_id
# CampJa00                   186.3   32    47    0  0.0      2006.0    2014.0
# OrtoKy00                   207.3   42    40    0  0.0      2005.0    2014.0
# PondCh00                   175.2   14    21    1  0.0      2011.0    2014.0
# CarrDa00                   153.7   23    56    0  0.0      2002.0    2012.0
# BatcCh00                   136.9   25    30    0  0.0      1998.0    2012.0
# ...                          ...  ...   ...  ...  ...         ...       ...
# BratZe00                    78.4   18    30    1  0.0      1954.0    1971.0
# StarBa00                   126.1   94    57    6  1.0      1956.0    1971.0
# RyanFr00                   127.3   57    27    3  0.0      1958.0    1970.0
# TensSt00                    99.3   10    23    1  0.0      1965.0    1970.0
# KappJo00                   115.9   24    21    3  0.0      1967.0    1970.0
#
# [182 rows x 35 columns]

# %% [markdown]
# # Train/Test Split

# %%
target = 'hof'
y = qb_df[target]
X = qb_df.drop(columns=target)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.2)

# %% [markdown]
# # Baseline

# %%
baseline_acc = y_train.value_counts(normalize=True).max()

print('Baseline Accuracy:', baseline_acc)
# Out:
# Baseline Accuracy: 0.8827586206896552

# %% [markdown]
# # Build Model - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
np.random.seed(42)

# %%
log_model = make_pipeline(
       StandardScaler(),
       LogisticRegression()
)

log_model.fit(X_train, y_train);

# %% [markdown]
# ## Check Metrics - Logistic Regression

# %%
print('Training Accuracy Score:', log_model.score(X_train, y_train))
print('Validation Accuracy Score:', log_model.score(X_val, y_val))
# Out:
# Training Accuracy Score: 0.9862068965517241
# Validation Accuracy Score: 0.9459459459459459

# %%
X_test = test.drop(columns=target)

y_pred_log = log_model.predict(X_test)

results3 = pd.DataFrame(y_pred_log, columns=['hof'], index=X_test.index)

# %%
results3[results3['hof'] == 1]
# Out:
#            hof
# player_id
# WilsRu00   1.0
# BreeDr00   1.0
# RodgAa00   1.0
# MahoPa00   1.0
# BradTo00   1.0
# RivePh00   1.0
# RyanMa00   1.0
# RoetBe00   1.0
# MannEl00   1.0
# PalmCa00   1.0
# RomoTo00   1.0
# MannPe00   1.0

# %%
from sklearn.inspection import permutation_importance

perm_imp = permutation_importance(log_model, X_val, y_val, n_jobs=-1, random_state=42)

data = {'mean_importance' : perm_imp['importances_mean'], 'std_importances' : perm_imp['importances_std']}

df = pd.DataFrame(data, index=X_val.columns)
df.sort_values('mean_importance', ascending=True, inplace=True)

df['mean_importance'].tail(15).plot(kind='barh')
plt.xlabel('Importance (change in accuracy)')
plt.ylabel('Feature')
plt.title('Permutation importance for logistic regression');

# %% [markdown]
# # Build Model - Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest_model = RandomForestClassifier(max_depth=2, n_estimators=500)

forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=500)

# %%
print('FOREST: Training Accuracy:', forest_model.score(X_train, y_train))
print('FOREST: VAl Accuracy:', forest_model.score(X_val, y_val))
# Out:
# FOREST: Training Accuracy: 0.9655172413793104
# FOREST: VAl Accuracy: 0.918918918918919

# %% [markdown]
# # See Predictions

# %%
y_pred_forest = forest_model.predict(X_test)

results = pd.DataFrame(y_pred_forest, columns=['hof'], index=X_test.index)

results[results['hof'] == 1]
# Out:
#            hof
# player_id
# WilsRu00   1.0
# BreeDr00   1.0
# RodgAa00   1.0
# BradTo00   1.0
# RivePh00   1.0
# RyanMa00   1.0
# RoetBe00   1.0
# MannEl00   1.0
# PalmCa00   1.0
# RomoTo00   1.0
# MannPe00   1.0

# %% [markdown]
# # Feature Importance

# %%
features = X_train.columns
importances = forest_model.feature_importances_

feature_importances = pd.Series(importances, index=features).sort_values()

feature_importances.tail(20).plot(kind='barh')
plt.xlabel('Information Gain')
# Out:
# Text(0.5, 0, 'Information Gain')

# %% [markdown]
# # Permutation Importance

# %%
from sklearn.inspection import permutation_importance

perm_imp = permutation_importance(forest_model, X_val, y_val, n_jobs=-1, random_state=42)

data = {'mean_importance' : perm_imp['importances_mean'], 'std_importances' : perm_imp['importances_std']}

df = pd.DataFrame(data, index=X_val.columns)
df.sort_values('mean_importance', ascending=True, inplace=True)

df['mean_importance'].tail(15).plot(kind='barh')
plt.xlabel('Importance (change in accuracy)')
plt.ylabel('Feature')
plt.title('Permutation importance for random forest model');

# %% [markdown]
# # Build Model - XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
boost_model = XGBClassifier(n_estimators=500, n_jobs=-1, random_state=42)

boost_model.fit(X_train, y_train);

# %%
print('Training accuracy:', boost_model.score(X_train, y_train))
print('Val accuracy:', boost_model.score(X_val, y_val))
# Out:
# Training accuracy: 1.0
# Val accuracy: 0.972972972972973

# %%
y_pred_boost = boost_model.predict(X_test)

results2 = pd.DataFrame(y_pred_boost, columns=['hof'], index=X_test.index)

# %%
results2[results2['hof'] == 1]
# Out:
#            hof
# player_id
# WilsRu00   1.0
# BreeDr00   1.0
# RodgAa00   1.0
# BradTo00   1.0
# RivePh00   1.0
# RyanMa00   1.0
# RoetBe00   1.0
# MannEl00   1.0
# PalmCa00   1.0
# RomoTo00   1.0
# MannPe00   1.0

# %%
from sklearn.inspection import permutation_importance

perm_imp = permutation_importance(boost_model, X_val, y_val, n_jobs=-1, random_state=42)

data = {'mean_importance' : perm_imp['importances_mean'], 'std_importances' : perm_imp['importances_std']}

df = pd.DataFrame(data, index=X_val.columns)
df.sort_values('mean_importance', ascending=True, inplace=True)

df['mean_importance'].tail(10).plot(kind='barh')
plt.xlabel('Importance (change in accuracy)')
plt.ylabel('Feature')
plt.title('Permutation importance for model_xgb');

# %% [markdown]
# # ROC-Curve compare Random Forest and XGBoost

# %%
from sklearn.metrics import plot_roc_curve

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(20,5))

plot_roc_curve(forest_model, X_val, y_val, ax=ax1)
plot_roc_curve(boost_model, X_val, y_val, ax=ax2)


ax1.plot([(0,0), (1,1)], color='grey', linestyle='--')
ax2.plot([(0,0), (1,1)], color='grey', linestyle='--')

ax1.set_title('Random Forest')
ax2.set_title('XGBoost')


plt.show()

# %% [markdown]
# # Random Forest with K-folds

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
forest_model1 = RandomForestClassifier()

param_space = {"criterion": ['gini', 'entropy'],
         "max_depth": [1, 2, 3, 4],
         "min_samples_leaf": [2, 3, 4, 5],
         "min_samples_split": [2, 3, 4, 5, 6],
         "n_estimators": [100, 200, 300, 400, 500],
         "max_samples" : [0.5, 0.6, 0.7, 0.8, 0.9, 1]
 }

forest_rand_search = RandomizedSearchCV(forest_model1, param_distributions=param_space, n_iter=20,
                                         scoring="accuracy", verbose=True, cv=StratifiedKFold(n_splits=5),
                                         n_jobs=-1, random_state=42)

forest_rand_search.fit(X, y)

# %%
forest_rand_search.best_params_

# %%
forest_rand_search.best_score_

# %%
y_pred_tree = forest_rand_search.predict(X_test)

results1 = pd.DataFrame(y_pred_tree, columns=['hof'], index=X_test.index)

# %%
results1[results1['hof'] == 1]
